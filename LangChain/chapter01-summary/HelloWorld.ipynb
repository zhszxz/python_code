# %% [markdown]
# # 1、获取大模型

# %%
#导入 dotenv 库的 load_dotenv 函数，用于加载环境变量文件（.env）中的配置
import dotenv
from langchain_openai import ChatOpenAI
import os

dotenv.load_dotenv()  #加载当前目录下的 .env 文件

os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
os.environ['OPENAI_BASE_URL'] = os.getenv("OPENAI_BASE_URL")

# 创建大模型实例
llm = ChatOpenAI(model="deepseek-v4-flash")

# 直接提供问题，并调用llm
response = llm.invoke("什么是大模型？")
print(response)
# Out:
# content='这是一个非常核心的问题。简单来说，**大模型** 是人工智能领域，特别是深度学习中的一种**大规模、通用性强的神经网络模型**。\n\n我们可以从以下几个关键点来理解它：\n\n### 1. “大”在何处？\n大模型的名字里就有“大”字，这个“大”主要体现在三个方面：\n\n-   **模型参数巨大**：参数可以理解为模型的“神经元”和它们之间连接的“权重”。传统模型参数量在百万或千万级别。而大模型的参数量通常在**数十亿（Billion）到数万亿（Trillion）**之间。比如，GPT-3（1750亿参数）、PaLM（5400亿参数）。\n-   **训练数据海量**：大模型需要从“互联网级别”的数据中学习，包括整个维基百科、海量书籍、论文、网页、代码、图片等。数据的规模通常是**TB乃至PB级别**。\n-   **计算资源庞大**：训练这样的大模型需要成千上万块高性能GPU（图形处理器，类似电脑显卡但更强）组成的超级计算集群，连续运行数周甚至数月，耗资巨大（从数百万到上亿美元）。\n\n### 2. “模型”指什么？\n这里的“模型”是一个数学模型，它本质上是一个**极度复杂的数学函数**。输入一个提示（如一句话、一张图），这个函数经过复杂的计算，输出一个合理的预测或生成结果（如一段文字、一张新图）。\n\n### 3. 核心特征：涌现能力\n大模型最神奇的地方在于，当模型的规模（参数、数据、算力）超过某个“临界点”后，会**涌现**出小模型不具备的、意想不到的能力。这些能力不是被明确编程进去的，而是从海量数据中“悟”出来的。主要涌现能力包括：\n\n-   **上下文学习**：不需要重新训练，给它几个例子（Few-shot），它就能举一反三，完成类似任务。\n-   **推理能力**：能进行一定程度的逻辑推理、数学计算、代码编写、常识判断。\n-   **思维链**：通过在回答中加入“让我们一步步思考”等引导，它能像人类一样分解复杂问题，提高答案的准确性。\n\n### 4. 与传统AI模型的区别\n\n| 特性 | 传统AI模型 （小模型） | 大模型 |\n| :--- | :--- | :--- |\n| **大小** | 小，几百万到几千万参数 | 巨大，数十亿到数万亿参数 |\n| **能力** | **专用**：针对单个任务设计（如仅做翻译、仅识别猫） | **通用**：一个模型能做几百种任务（翻译、问答、写诗、编程、总结、创作等） |\n| **训练方式** | 需针对每个任务，用大量**标注数据**（人工打好标签的数据）专门训练 | 主要在**海量无标注数据**上进行自监督学习，再少量微调即可适应众多任务 |\n| **应用模式** | 需要为每个任务建立和部署一个模型 | **一个模型，多种应用**，可以通过对话、API（应用程序编程接口）接口等方式直接使用 |\n| **准确性** | 在特定领域可能很高 | 在广泛任务上表现优秀，但可能在深度专业知识上不如专用模型 |\n\n### 5. 典型的例子\n你肯定听说过它们的一些“代表”：\n\n-   **文本类**：OpenAI的**GPT系列**（如ChatGPT背后的GPT-3.5和GPT-4）、Google的**PaLM**和**Gemini**、Meta的**LLaMA**系列、国内的**文心一言**、**通义千问**等。\n-   **图像/多模态类**：OpenAI的**DALL-E 3**（文生图）、Google的**Gemini**（能处理文字、图片、视频、代码）、Stability AI的**Stable Diffusion**等。\n\n### 总结\n**大模型可以理解为一种“能力超强、知识渊博”的超级AI大脑。** 它通过学习海量互联网数据，掌握了许多知识、语言模式甚至逻辑规律。它不再是一个只会单一技能的“工具”，而是一个具有**通用能力**的基础平台。开发者可以在这个平台上快速构建各种智能应用，就像在电脑操作系统上开发软件一样。**因此，大模型也被称为“基础模型”或“基石模型”。**\n\n如果用一个比喻来理解：**传统AI模型是专门做一道菜的“专用厨具”（比如切菜机），而大模型是拥有大量菜谱、精通各种烹饪手法的“天才大厨”**，你只需要告诉它你想吃什么，它就能为你做出来。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1173, 'prompt_tokens': 8, 'total_tokens': 1181, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 193, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '7e7a2109-16ea-4676-9065-ca75545bf98d', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--658a67fe-d1c4-4468-82f8-854d06ea7307-0' usage_metadata={'input_tokens': 8, 'output_tokens': 1173, 'total_tokens': 1181, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 193}}
# content='这是一个很好的问题。“大模型”是当前人工智能领域最热门的概念之一。简单来说，可以把它理解为一个**超级大脑**，但它不是由生物神经元组成的，而是由海量的数学参数和复杂的计算单元构成的。\n\n下面我们从几个层面来详细拆解一下：\n\n### 一、最直观的理解：一个“超级学霸”\n\n想象一个学生，给他读了全世界大部分图书馆的书、互联网上的所有网页、无数的代码、图片和视频。他读了这些内容后，并没有死记硬背，而是从中学会了语言规律、知识关联、逻辑推理、甚至一些创造力。\n\n这个大模型就是那个“超级学霸”。你问它问题，它不是去“百度一下”然后复制粘贴，而是基于它所学到的浩瀚知识，自己“理解”问题，然后“创作”出一个最合理、最连贯的回答。\n\n### 二、技术层面的核心定义\n\n从技术上来说，大模型是：\n\n1.  **深度学习模型**： 它的基础是深度学习，一种模拟人脑神经网络的计算模型。\n2.  **参数巨大**： “大”字是关键。传统模型可能有几百万、几千万个参数。而大模型的参数数量通常达到**十亿（Billion）、千亿甚至万亿**级别。比如 GPT-3 有 1750 亿个参数。\n3.  **数据海量**： 它是在几乎整个互联网的文本、图片、代码等海量数据上训练出来的。训练数据量通常以 TB（太字节）甚至 PB（拍字节）计算。\n4.  **通用性强**： 不像之前的AI模型，一个模型只做一件事（比如只识别猫的图片）。大模型是一种“基础模型”，通过一些微调或提示，就能完成翻译、写诗、编程、问答、总结、推理等各种各样的任务。\n\n### 三、大模型的几个关键特点\n\n1.  **涌现能力**： 当模型规模大到一定程度，它会突然“涌现”出一些在小模型中没有的能力，比如进行逻辑推理、理解上下文语境、甚至展现一些“常识”。这是最令人兴奋也最神秘的一点。\n2.  **规模法则**： 研究发现，在模型大小、数据量和计算量这三方面一起增大时，模型的能力会稳定地提升。这就是为什么大家会“军备竞赛”般地训练越来越大的模型。\n3.  **基于Transformer架构**： 绝大多数现代大模型都使用一种叫做 **Transformer** 的神经网络架构。它最核心的机制是**注意力机制**，让模型能够动态地关注输入信息中最重要的部分，而不是死板地处理所有内容。\n\n### 四、大模型的典型代表\n\n-   **OpenAI GPT系列**： (GPT-3, GPT-4, GPT-4o等) 引爆了这次AI浪潮，也是ChatGPT的“大脑”。\n-   **Google Gemini系列**： 谷歌的旗舰多模态大模型。\n-   **Meta LLaMA系列**： 开源大模型的重要代表，推动了学术和社区发展。\n-   **Claude系列**： Anthropic公司开发，注重安全性和有用性。\n-   **文心一言**、**通义千问**、**Kimi** 等： 国内优秀的国产大模型。\n\n### 五、它是如何工作的？一个简化的流程\n\n1.  **训练（学习）**： 把海量的文本数据输入到模型中。模型的任务是预测下一个字（词）是什么。比如给它“我今天吃”，它会预测出“饭”或者“苹果”等。通过数万亿次这样的预测和纠正，模型内部数亿个参数不断调整，最终学会了语言的模式、语法、事实和逻辑。\n2.  **推理（回答）**： 当你提问时，模型会把你输入的句子作为一个起点，然后基于它学到的所有知识，一个词一个词地“生成”后续的文字。它每一次生成下一个词，都是基于前面所有生成的词和原始问题的上下文。\n\n### 六、大模型能做什么？（应用）\n\n-   **聊天和问答**： ChatGPT、文心一言等。\n-   **内容生成**： 写文章、邮件、剧本、诗歌、代码。\n-   **翻译和总结**： 翻译多国语言，总结长文档。\n-   **编程辅助**： GitHub Copilot，解释代码、写代码、查bug。\n-   **多模态能力**： 最新的模型还能理解图片、生成图片、甚至生成视频（如Sora）。\n\n### 七、局限性\n\n它不是万能的，也有明显缺点：\n\n-   **“一本正经地胡说八道”**： 它可能根据统计规律生成听起来合理但事实错误的信息（称为“幻觉”）。\n-   **缺乏真正理解**： 它不理解它所说的内容，只是进行概率预测。\n-   **高昂成本**： 训练一个顶级大模型需要数亿美元的电力和算力。\n-   **偏见和伦理问题**： 训练数据中的偏见会被模型学到和放大。\n\n### 总结\n\n**大模型 = 海量参数 + 海量数据 + 巨大算力 + Transformer架构**，最终产生了一个具备**涌现能力**的、**通用性极强**的**人工智能基础模型**。它不是一个会单一任务的工具，而是一个具备了“思考”和“创作”潜力的数字大脑，正在深刻地改变我们与技术交互的方式。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1300, 'prompt_tokens': 8, 'total_tokens': 1308, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 178, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '30d7112d-4fbc-4a31-8c27-e30f0d25af99', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--5d6df49e-2c3d-4bf9-adc2-491671a30f3e-0' usage_metadata={'input_tokens': 8, 'output_tokens': 1300, 'total_tokens': 1308, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 178}}

# %% [markdown]
# # 2、使用提示词模板

# %%
from langchain_core.prompts import ChatPromptTemplate

# 需要注意的一点是，这里需要指明具体的role，在这里是system和用户
prompt = ChatPromptTemplate.from_messages([
    ("system", "你是世界级的技术文档编写者"),
    ("user", "{input}")  # {input}为变量
])

# 我们可以把prompt和具体llm的调用和在一起。
chain = prompt | llm
message = chain.invoke({"input": "大模型中的LangChain是什么?"})
print(message)

# print(type(message))
# Out:
# content='## LangChain：大型语言模型的应用开发框架\n\n### 1. 概述\n\nLangChain 是一个开源框架，旨在简化基于大型语言模型（LLM）的应用程序开发。它为开发者提供了一套标准化的接口和组件，用于将 LLM 与外部数据源、工具及系统进行集成与编排，从而构建出复杂、有状态且上下文感知的 AI 应用。\n\n### 2. 核心问题与设计目标\n\n直接使用 LLM 面临诸多挑战：\n\n- **无状态性**：每次调用都是独立会话，缺乏记忆与上下文。\n- **知识截断**：模型训练数据截止于特定时间点，无法访问实时或私有信息。\n- **工具缺失**：LLM 无法自主调用外部 API、数据库或执行计算。\n- **组合复杂性**：将多个 prompt、多个模型步骤、多轮对话组装成工作流需要大量样板代码。\n\nLangChain 通过以下设计解决这些问题：\n\n- **模块化抽象**：将 LLM、数据源、工具、记忆、代理等抽象为可替换的组件。\n- **链式组合**：支持将多个组件通过“Chain”串联，形成可复用的处理流水线。\n- **代理机制**：赋予 LLM 自主规划与工具调用能力，实现动态决策。\n- **集成生态**：预封装各类 LLM 提供商（OpenAI、Anthropic、Hugging Face 等）、向量数据库（Chroma、Pinecone 等）、文档加载器（PDF、CSV、网页等）。\n\n### 3. 核心组件\n\n#### 3.1 Models（模型）\n- **LLM 封装**：统一接口调用不同公司的大模型。支持温度、max_tokens 等参数。\n- **Chat Models**：专门针对多轮对话的模型封装（如 GPT-4、Claude），传入消息列表（System、Human、AI）。\n- **Embedding Models**：将文本转换为向量，用于语义搜索与相似度计算。\n\n#### 3.2 Prompts（提示）\n- **Prompt Templates**：将固定指令与动态变量分离，如 `"请回答关于{product}的常见问题"`。\n- **Few-shot Example Selectors**：根据输入自动选择最相关的样本。\n- **Output Parsers**：将模型输出解析为结构化格式（JSON、列表等），便于下游处理。\n\n#### 3.3 Memory（记忆）\n- 管理对话或状态的持久化，支持多种策略：\n  - **BufferMemory**：保留最近 N 轮对话。\n  - **SummaryMemory**：压缩历史为摘要。\n  - **VectorStoreMemory**：基于向量检索的长期记忆。\n  - **Custom Memory**：允许开发者自定义存储后端（Redis、数据库等）。\n\n#### 3.4 Chains（链）\n- 基本的处理单元，串联多个步骤。常见类型：\n  - **LLMChain**：一个提示 + 一个模型 + 一个解析器。\n  - **SequentialChain**：多步顺序执行，输出传递。\n  - **RouterChain**：根据输入内容动态选择子链。\n  - **TransformChain**：在步骤间进行数据预处理/后处理。\n\n#### 3.5 Agents（代理）\n- 让 LLM 自主决定使用哪些工具以及调用顺序。代理不断循环：思考 → 行动 → 观察 → 思考……\n- **Task-specific Agents**：如 ReAct、Self-ask With Search。\n- **Toolkits**：预定义的工具集合（如 SQL 数据库、文件系统、数学计算器、Web 搜索）。\n\n#### 3.6 Indexes（索引与检索）\n- **Document Loaders**：从 PDF、Word、网页、数据库加载非结构化文本。\n- **Text Splitters**：将长文档分块，保持语义边界（按段落、递归字符分割）。\n- **Vector Stores**：存储嵌入向量，支持相似性搜索。\n- **Retrievers**：从向量存储中提取相关文档块。\n\n### 4. 典型应用场景\n\n| 场景 | 实现方式 |\n|------|----------|\n| **文档问答（RAG）** | 加载文档 → 分块 → 嵌入存储 → 用户提问 → 检索相关块 → 注入 prompt → LLM 回答。 |\n| **智能客服机器人** | 结合记忆模块维护会话上下文，通过工具查询订单系统、知识库。 |\n| **数据查询与分析** | 代理调用 SQL 数据库、计算器、可视化库，根据自然语言生成报告。 |\n| **多步骤任务代理** | 如：用户需求 → 搜索 → 读取网页 → 提取信息 → 写入文件。 |\n| **格式化信息提取** | 使用输出解析器从非结构化文本中抽取实体并生成 JSON。 |\n\n### 5. 生态系统与扩展\n\n- **LangChain Hub**：共享 prompt、链、agent 等的社区平台。\n- **LangServe**：将 LangChain 应用部署为 REST API。\n- **LangSmith**：调试、测试、监控 LLM 流水线的开发平台。\n- 第三方集成：超过 100 个提供商的插件（数据库、SaaS 工具、搜索引擎）。\n\n### 6. 代码示例（简单对话链）\n\n```python\nfrom langchain.llms import OpenAI\nfrom langchain.chains import LLMChain\nfrom langchain.prompts import PromptTemplate\n\n# 创建模型\nllm = OpenAI(temperature=0.7, model_name="gpt-3.5-turbo")\n\n# 定义提示模板\ntemplate = """你是一位{role}。请回答用户的问题。\n用户问题：{question}\n你的回答："""\nprompt = PromptTemplate(template=template, input_variables=["role", "question"])\n\n# 构建链\nchain = LLMChain(llm=llm, prompt=prompt)\n\n# 执行\nresult = chain.run(role="资深金融顾问", question="当前通胀环境下，如何配置资产？")\nprint(result)\n```\n\n### 7. 局限性\n\n- **代理行为不可预测**：自主调用工具可能产生意外结果，需配合人工审核。\n- **Token 限制**：长上下文（如多链持久化记忆）会消耗大量 token，成本高。\n- **调试复杂**：内部隐式推理过程在黑盒模型下难以精确追溯。\n- **版本演进快**：API 与设计模式在不同版本间有较大变更。\n\n### 8. 总结\n\nLangChain 填补了 LLM 与真实世界应用程序之间的鸿沟。它通过模块化链、智能代理、可插拔记忆与检索，使构建健壮、可扩展的 LLM 应用成为可能。对于希望快速用大模型完成实际任务的开发者，LangChain 已成为事实上的标准工具。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1517, 'prompt_tokens': 18, 'total_tokens': 1535, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 82, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 18}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'd0c57b49-8d23-4481-8dd9-6f9505d81764', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--3b49af6d-1e31-478e-9d9b-53aacc0e83c6-0' usage_metadata={'input_tokens': 18, 'output_tokens': 1517, 'total_tokens': 1535, 'input_token_details': {'cache_read': 0}, 'output_to ...

# %% [markdown]
# # 3、 使用输出解析器

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser,JsonOutputParser

# 初始化模型
llm = ChatOpenAI(model="deepseek-v4-flash")

# 创建提示模板
prompt = ChatPromptTemplate.from_messages([
    ("system", "你是世界级的技术文档编写者。"),
    ("user", "{input}")
])

# 使用输出解析器
# output_parser = StrOutputParser()
output_parser = JsonOutputParser()

# 将其添加到上一个链中
# chain = prompt | llm
chain = prompt | llm | output_parser

# 调用它并提出同样的问题。答案是一个字符串，而不是ChatMessage
# chain.invoke({"input": "LangChain是什么?"})
chain.invoke({"input": "LangChain是什么? 用JSON格式回复，问题用question，回答用answer"})
# Out:
# {'question': 'LangChain是什么?',
#  'answer': 'LangChain是一个用于开发由大型语言模型（LLM）驱动的应用程序的开源框架。它提供了一套工具、组件和接口，帮助开发者将LLM与外部数据源、API、数据库等集成，从而实现复杂的链式调用、智能代理、记忆管理等能力。LangChain简化了构建基于LLM的应用（如聊天机器人、问答系统、文档分析工具）的流程，并支持多种模型提供商和部署方式。'}

# %% [markdown]
# # 4、使用向量存储

# %%
# 导入和使用 WebBaseLoader
from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
        web_path="https://www.gov.cn/xinwen/2020-06/01/content_5516649.htm",
        bs_kwargs=dict(parse_only=bs4.SoupStrainer(id="UCAP-CONTENT"))
    )
docs = loader.load()
# print(docs)

# 对于嵌入模型，这里通过 API调用
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")


from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 使用分割器分割文档
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
documents = text_splitter.split_documents(docs)
print(len(documents))
# 向量存储  embeddings 会将 documents 中的每个文本片段转换为向量，并将这些向量存储在 FAISS 向量数据库中
vector = FAISS.from_documents(documents, embeddings)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# 0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\.conda\envs\myenv\lib\site-packages\langchain_community\vectorstores\faiss.py:56, in dependable_faiss_import(no_avx2)
#      55     else:
# ---> 56         import faiss
#      57 except ImportError:
#
# ModuleNotFoundError: No module named 'faiss'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 26
#      24 print(len(documents))
#      25 # 向量存储  embeddings 会将 documents 中的每个文本片段转换为向量，并将这些向量存储在 FAISS 向量数据库中
# ---> 26 vector = FAISS.from_documents(documents, embeddings)
#
# File ~\.conda\envs\myenv\lib\site-packages\langchain_core\vectorstores\base.py:837, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     834     if any(ids):
#     835         kwargs["ids"] = ids
# --> 837 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~\.conda\envs\myenv\lib\site-packages\langchain_community\vectorstores\faiss.py:1044, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1025 """Construct FAISS wrapper from raw documents.
#    1026
#    1027 This is a user friendly interface that:
#    (...)
#    1041         faiss = FAISS.from_texts(texts, embeddings)
#    1042 """
#    1043 embeddings = embedding.embed_documents(texts)
# -> 1044 return cls.__from(
#    1045     texts,
#    1046     embeddings,
#    1047     embedding,
#    1048     metadatas=metadatas,
#    1049     ids=ids,
#    1050     **kwargs,
#    1051 )
#
# File ~\.conda\envs\myenv\lib\site-packages\langchain_community\vectorstores\faiss.py:996, in FAISS.__from(cls, texts, embeddings, embedding, metadatas, ids, normalize_L2, distance_strategy, **kwargs)
#     984 @classmethod
#     985 def __from(
#     986     cls,
#    (...)
#     994     **kwargs: Any,
#     995 ) -> FAISS:
# --> 996     faiss = dependable_faiss_import()
#     997     if distance_strategy == DistanceStrategy.MAX_INNER_PRODUCT:
#     998         index = faiss.IndexFlatIP(len(embeddings[0]))
#
# File ~\.conda\envs\myenv\lib\site-packages\langchain_community\vectorstores\faiss.py:58, in dependable_faiss_import(no_avx2)
#      56         import faiss
#      57 except ImportError:
# ---> 58     raise ImportError(
#      59         "Could not import faiss python package. "
#      60         "Please install it with `pip install faiss-gpu` (for CUDA supported GPU) "
#      61         "or `pip install faiss-cpu` (depending on Python version)."
#      62     )
#      63 return faiss
#
# ImportError: Could not import faiss python package. Please install it with `pip install faiss-gpu` (for CUDA supported GPU) or `pip install faiss-cpu` (depending on Python version).

# %% [markdown]
# # 5、RAG(检索增强生成)

# %%
from langchain_core.prompts import PromptTemplate

retriever = vector.as_retriever()
retriever.search_kwargs = {"k": 3}
docs = retriever.invoke("建设用地使用权是什么？")

# for i,doc in enumerate(docs):
#     print(f"⭐第{i+1}条规定：")
#     print(doc)

# 6.定义提示词模版
prompt_template = """
你是一个问答机器人。
你的任务是根据下述给定的已知信息回答用户问题。
确保你的回复完全依据下述已知信息。不要编造答案。
如果下述已知信息不足以回答用户的问题，请直接回复"我无法回答您的问题"。

已知信息:
{info}

用户问：
{question}

请用中文回答用户问题。
"""
# 7.得到提示词模版对象
template = PromptTemplate.from_template(prompt_template)

# 8.得到提示词对象
prompt = template.format(info=docs, question='建设用地使用权是什么？')

## 9. 调用LLM
response = llm.invoke(prompt)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 from langchain_core.prompts import PromptTemplate
# ----> 3 retriever = vector.as_retriever()
#       4 retriever.search_kwargs = {"k": 3}
#       5 docs = retriever.invoke("建设用地使用权是什么？")
#
# NameError: name 'vector' is not defined

# %% [markdown]
# # 6、使用Agent

# %%
from langchain.tools.retriever import create_retriever_tool

# 检索器工具
retriever_tool = create_retriever_tool(
    retriever,
    "CivilCodeRetriever",
    "搜索有关中华人民共和国民法典的信息。关于中华人民共和国民法典的任何问题，您必须使用此工具!",
)

tools = [retriever_tool]

from langchain import hub
from langchain.agents import create_openai_functions_agent
from langchain.agents import AgentExecutor

# https://smith.langchain.com/hub
prompt = hub.pull("hwchase17/openai-functions-agent")

agent = create_openai_functions_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# 运行代理
agent_executor.invoke({"input": "建设用地使用权是什么"})
# Out:
# D:\developTools\miniconda3\envs\pyth310\lib\site-packages\langsmith\client.py:272: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# > Entering new AgentExecutor chain...
#
# Invoking: `CivilCodeRetriever` with `{'query': '建设用地使用权'}`
#
#
# 第三百四十五条　建设用地使用权可以在土地的地表、地上或者地下分别设立。
# 第三百四十六条　设立建设用地使用权，应当符合节约资源、保护生态环境的要求，遵守法律、行政法规关于土地用途的规定，不得损害已经设立的用益物权。
# 第三百四十七条　设立建设用地使用权，可以采取出让或者划拨等方式。
# 工业、商业、旅游、娱乐和商品住宅等经营性用地以及同一土地有两个以上意向用地者的，应当采取招标、拍卖等公开竞价的方式出让。
# 严格限制以划拨方式设立建设用地使用权。
# 第三百四十八条　通过招标、拍卖、协议等出让方式设立建设用地使用权的，当事人应当采用书面形式订立建设用地使用权出让合同。
# 建设用地使用权出让合同一般包括下列条款：
# （一）当事人的名称和住所；
# （二）土地界址、面积等；
# （三）建筑物、构筑物及其附属设施占用的空间；
# （四）土地用途、规划条件；
# （五）建设用地使用权期限；
# （六）出让金等费用及其支付方式；
# （七）解决争议的方法。
# 第三百四十九条　设立建设用地使用权的，应当向登记机构申请建设用地使用权登记。建设用地使用权自登记时设立。登记机构应当向建设用地使用权人发放权属证书。
#
# 第三百五十条　建设用地使用权人应当合理利用土地，不得改变土地用途；需要改变土地用途的，应当依法经有关行政主管部门批准。
# 第三百五十一条　建设用地使用权人应当依照法律规定以及合同约定支付出让金等费用。
# 第三百五十二条　建设用地使用权人建造的建筑物、构筑物及其附属设施的所有权属于建设用地使用权人，但是有相反证据证明的除外。
# 第三百五十三条　建设用地使用权人有权将建设用地使用权转让、互换、出资、赠与或者抵押，但是法律另有规定的除外。
# 第三百五十四条　建设用地使用权转让、互换、出资、赠与或者抵押的，当事人应当采用书面形式订立相应的合同。使用期限由当事人约定，但是不得超过建设用地使用权的剩余期限。
# 第三百五十五条　建设用地使用权转让、互换、出资或者赠与的，应当向登记机构申请变更登记。
# 第三百五十六条　建设用地使用权转让、互换、出资或者赠与的，附着于该土地上的建筑物、构筑物及其附属设施一并处分。
# 第三百五十七条　建筑物、构筑物及其附属设施转让、互换、出资或者赠与的，该建筑物、构筑物及其附属设施占用范围内的建设用地使用权一并处分。
#
# 第三百五十八条　建设用地使用权期限届满前，因公共利益需要提前收回该土地的，应当依据本法第二百四十三条的规定对该土地上的房屋以及其他不动产给予补偿，并退还相应的出让金。
# 第三百五十九条　住宅建设用地使用权期限届满的，自动续期。续期费用的缴纳或者减免，依照法律、行政法规的规定办理。
# 非住宅建设用地使用权期限届满后的续期，依照法律规定办理。该土地上的房屋以及其他不动产的归属，有约定的，按照约定；没有约定或者约定不明确的，依照法律、行政法规的规定办理。
# 第三百六十条　建设用地使用权消灭的，出让人应当及时办理注销登记。登记机构应当收回权属证书。
# 第三百六十一条　集体所有的土地作为建设用地的，应当依照土地管理的法律规定办理。
# 第十三章　宅基地使用权
# 第三百六十二条　宅基地使用权人依法对集体所有的土地享有占有和使用的权利，有权依法利用该土地建造住宅及其附属设施。
# 第三百六十三条　宅基地使用权的取得、行使和转让，适用土地管理的法律和国家有关规定。
# 第三百六十四条　宅基地因自然灾害等原因灭失的，宅基地使用权消灭。对失去宅基地的村民，应当依法重新分配宅基地。建设用地使用权是指由国家或集体出让或划拨给使用者在一定期间内对特定土地进行建设、开发和利用的权利。根据中华人民共和国民法典的相关规定，建设用地使用权的具体内容包括：
#
# 1. **设立方式**：建设用地使用权可以通过出让或划拨的方式设立，且出让方式一般使用公开招标、拍卖等方式，特别是对于经营性用地。
#
# 2. **合同内容**：建设用地使用权出让合同应包含当事人的信息、土地界址、面积、用途、使用权期限、出让金等费用及解决争议的方法。
#
# 3. **登记**：建设用地使用权需向登记机构申请登记，登记后方可正式设立，并会发放权属证书。
#
# 4. **合理利用和用途变更**：使用权人应合理利用土地，不得擅自改变土地用途，如需变更需经过相关行政部门的批准。
#
# 5. **转让和抵押**：建设用地使用权人有权转让、出资、赠与或抵押该使用权，但需遵守法律规定。
#
# 6. **使用权期限**：住宅建设用地使用权在期限届满后可以自动续期，而非住宅用地的续期则需依法办理。
#
# 7. **补偿机制**：如因公共利益需要收回土地，建设用地使用权人有权获得相应的补偿。
#
# 上述内容为建设用地使用权的基本信息和法律规定。
#
# > Finished chain.
# {'input': '建设用地使用权是什么',
#  'output': '建设用地使用权是指由国家或集体出让或划拨给使用者在一定期间内对特定土地进行建设、开发和利用的权利。根据中华人民共和国民法典的相关规定，建设用地使用权的具体内容包括：\n\n1. **设立方式**：建设用地使用权可以通过出让或划拨的方式设立，且出让方式一般使用公开招标、拍卖等方式，特别是对于经营性用地。\n\n2. **合同内容**：建设用地使用权出让合同应包含当事人的信息、土地界址、面积、用途、使用权期限、出让金等费用及解决争议的方法。\n\n3. **登记**：建设用地使用权需向登记机构申请登记，登记后方可正式设立，并会发放权属证书。\n\n4. **合理利用和用途变更**：使用权人应合理利用土地，不得擅自改变土地用途，如需变更需经过相关行政部门的批准。\n\n5. **转让和抵押**：建设用地使用权人有权转让、出资、赠与或抵押该使用权，但需遵守法律规定。\n\n6. **使用权期限**：住宅建设用地使用权在期限届满后可以自动续期，而非住宅用地的续期则需依法办理。\n\n7. **补偿机制**：如因公共利益需要收回土地，建设用地使用权人有权获得相应的补偿。\n\n上述内容为建设用地使用权的基本信息和法律规定。'}
