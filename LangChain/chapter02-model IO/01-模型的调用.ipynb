# %% [markdown]
# # 1、 模型调用的分类
#
# 角度1：按照模型功能的不同
#
# 非对话模型：（LLMs、Text Model）
#
# 对话模型：（Chat Models）  (推荐)
#
# 嵌入模型：（Embedding Models） (放到最后RAG章节讲解)
#
#
# 角度2：按照模型调用时，参数书写的位置的不同（api-key、base_url、model-name）
#
# 硬编码的方式：将参数书写在代码中
#
# 使用环境变量的方式
#
# 使用配置文件的方式 (推荐)
#
# 角度3：具体API的调用
#
# 使用LangChain提供的API (推荐)
#
# 使用OpenAI 官方的API
#
# 使用其它平台提供的API
#
#
# # 2、角度1：对话模型的调用

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
import os
import dotenv

dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")

########核心代码############
chat_model = ChatOpenAI(model="deepseek-v4-flash")

messages = [
    SystemMessage(content="你是人工智能助手，你叫小智"),
    HumanMessage(content="你好，我是小明，很高兴认识你")
]

#输入：list[basemessage]
#输出：AIMessage
response = chat_model.invoke(messages)  # 输入消息列表

print(type(response))  # <class 'langchain_core.messages.ai.AIMessage'>
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 你好小明！我是小智，很高兴认识你！有什么可以帮你的吗？😊

# %% [markdown]
# # 3、角度2：参数位置不同举例
#
#
# ## 3.1 硬编码的方式
#
# 以对话模型为例：

# %%
from langchain_openai import ChatOpenAI

# 调用对话模型：
chat_model = ChatOpenAI(
    #必须要设置的3个参数
    model="deepseek-v4-flash",  #默认使用的是gpt-3.5-turbo模型
    base_url="https://api.deepseek.com",
    api_key="",

)

# 调用模型
response = chat_model.invoke("什么是langchain?")

# 查看响应的文本
print(response.content)
# Out:
# LangChain 是一个开源框架，专门用于构建基于**大语言模型（LLM）** 的应用程序。它的核心目标是把复杂、多步骤的 AI 任务拆解成可组合的模块，让开发者能更容易地将 LLM 与其他工具、数据源或系统连接起来。
#
# 简单来说，你可以把 LangChain 想象成一个**“乐高积木”系统**，每块积木（组件）完成一个功能（比如调用 LLM、读取 PDF、搜索网络），而 LangChain 提供了将这些积木组合成完整应用的“接口”和“说明书”。
#
# ### LangChain 的核心概念
#
# 1.  **模型（Models）**：支持各种 LLM，如 OpenAI 的 GPT、Anthropic 的 Claude、Google 的 Gemini、Meta 的 LLaMA，以及开源模型。你可以一键切换模型，而不需要重写代码。
#
# 2.  **提示（Prompts）**：管理输入给 LLM 的指令。包括提示模板（Template）、少量样本示例（Few-shot Examples）、动态变量填充等。例如，自动生成一个“翻译以下句子为法语”的提示模板。
#
# 3.  **记忆（Memory）**：让 LLM 拥有短期或长期对话记忆。比如在聊天机器人中记住用户过去说过的话（如“我之前说我喜欢猫”），而不是每次对话都从零开始。
#
# 4.  **链（Chains）**：**这是 LangChain 最核心的概念**。链将多个组件串联起来，形成一个有序的工作流。例如：
#     -   **简单链**：接收用户输入 → 调用 LLM → 输出结果。
#     -   **复杂链**：先检索相关文档 → 将文档和用户问题拼接成提示 → 调用 LLM → 格式化输出 → 再检查结果的有效性。
#
# 5.  **代理（Agents）**：让 LLM 能够**自主决定**要调用哪些工具来完成任务。比如：
#     -   用户问：“今天北京气温多少？顺便帮我查一下最近的咖啡馆。”
#     -   代理会：先调用天气 API → 再调用地图 API → 最后整合结果回答用户。
#     -   代理内嵌了“推理+行动”的循环（ReAct模式），这是实现自动化任务的关键。
#
# 6.  **检索增强生成（RAG）**：将数据（如 PDF、数据库、网页）向量化存储，用户提问时先搜索最相关的信息段，再连同问题一起发给 LLM。这种方法能降低 LLM 的幻觉（编造事实），并回答私有数据问题（比如公司内部手册）。
#
# ### 为什么 LangChain 如此流行？
#
# -   **降低开发门槛**：不用从零搭建复杂的 LLM 应用。比如，实现一个能检索公司文档并回答问题的客服机器人，用 LangChain + ChromaDB 可能只需几十行代码。
# -   **支持多种模型和工具**：同一套代码可以切换不同的 LLM，也可以集成 Slack、邮件、数据库、搜索引擎等。
# -   **社区和生态**：贡献者众多，已有大量官方和第三方的“集成”（Integrations），比如与 LangSmith（调试工具）、LangServe（部署工具）配套使用。
#
# ### 一个简单的例子
#
# 假设你想做个**PDF问答机器人**。用 LangChain 流程如下：
#
# 1.  **加载**：用 `PyPDFLoader` 读取 PDF 文件。
# 2.  **切分**：用 `TextSplitter` 将长文本切成小段（chunks）。
# 3.  **向量化**：用 `OpenAIEmbeddings` 将每段文字转为向量并存入向量数据库（如 FAISS）。
# 4.  **检索**：用户提问，系统在向量库中找到最相关的几段文字。
# 5.  **生成**：把“检索到的内容”+“用户问题”打包成提示，发给 LLM，得到答案。
#
# ### 适用场景
#
# -   文档问答（合同、论文、内部知识库）
# -   自动化工作流（数据整理、自动发邮件）
# -   智能客服（能接入公司系统）
# -   代码生成与调试
# -   多轮对话（带长期记忆的聊天机器人）
#
# ### 一点提醒
#
# LangChain 虽然强大，但早期版本被部分开发者认为**“过度抽象”**（把简单事情复杂化）或更新过快。现在（2024-2025年）版本趋于稳定，但如果你的需求非常轻量（比如只是调用一个 API），直接写几行代码可能更简单。LangChain**最适合**需要**复杂编排**、**多工具集成**或**需要快速原型验证**的场景。
#
# 如果你刚接触，建议先尝试它的官方教程“RAG 应用”或“简单聊天机器人”，很快就能感受到它的价值。

# %% [markdown]
# ## 3.2 使用环境变量的方式
#
# 说明：使用环境变量的方式，在jupyter中执行不合适，需要在.py文件中执行

# %%
from langchain_openai import ChatOpenAI
import os

print(os.environ["OPENAI_BASE_URL"])
print(os.environ["OPENAI_API_KEY"])

# 1、获取对话模型：
chat_model = ChatOpenAI(
    # 必须要设置的3个参数
    model_name="deepseek-v4-flash",  # 默认使用的是gpt-3.5-turbo模型
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],

)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)

# %% [markdown]
# ## 3.3 使用配置文件的方式（推荐）
#
# 使用.env的配置文件
#
# 方式1：

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

#加载配置文件
dotenv.load_dotenv()

# 1、获取对话模型：
chat_model = ChatOpenAI(
    #必须要设置的3个参数
    model_name="deepseek-v4-flash",  #默认使用的是gpt-3.5-turbo模型
    base_url=os.getenv("OPENAI_BASE_URL"),
    api_key=os.getenv("OPENAI_API_KEY1"),

)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)
# Out:
# content='LangChain 是一个开源的 **大语言模型（LLM）应用开发框架**。简单来说，它就像一套“乐高积木”和“说明书”，帮助开发者更高效、更轻松地构建基于大语言模型的复杂应用程序。\n\n### 核心目标\n\n直接调用 OpenAI 等大模型的 API 虽然简单，但构建一个真正有用的智能应用（比如能联网查询、访问公司数据库、记住历史对话的机器人）会非常繁琐。LangChain 的出现就是为了解决这些痛点，它的核心目标在于：\n\n1.  **连接与集成**：将大模型与外部数据源（如 PDF、网页、数据库）、工具（如搜索引擎、计算器、代码解释器）、API 以及其他 AI 模型无缝连接。\n2.  **管理状态与记忆**：方便地实现多轮对话的记忆功能。\n3.  **构建复杂工作流**：将多个模型调用和逻辑步骤组合成一个链条（Chain）或更高级的代理（Agent），以完成复杂的任务。\n\n### 核心核心组成部分\n\n1.  **模型（Models）**：统一的接口来调用各种大模型，包括：\n    -   **LLM**（如 GPT-4、Claude、文心一言）\n    -   **聊天模型**（专门用于对话的模型）\n    -   **嵌入模型**（将文本转换为向量，用于语义搜索）\n\n2.  **提示词（Prompts）**：提供模板、示例管理和动态构建提示词的工具，帮助你更好地“指挥”大模型。\n\n3.  **链（Chains）**：**最关键的概念之一**。它将多个步骤（比如：调用一个模型 -> 得到结果 -> 处理结果 -> 再调用另一个模型）流程化。例如，一个简单的链可以是：`接收用户问题 -> 搜索知识库 -> 将搜索结果和问题组合成新提示 -> 调用LLM生成最终答案`。\n\n4.  **索引（Indexes） / 检索器（Retrievers）**：这是实现 **RAG（检索增强生成）** 技术的核心。它允许你将自己的文档（PDF、网页、Markdown）加载进来，切成小块，转换为向量存储，然后当用户提问时，能快速找出最相关的文本片段，让模型基于你提供的上下文来回答。这解决了大模型“知识过时”和“没有私有数据”的问题。\n\n5.  **记忆（Memory）**：让链或代理拥有“记性”。可以记录对话的历史，并在后续交互中参考，实现上下文感知的对话。\n\n6.  **代理（Agents）**：**另一个最酷的概念**。代理是一个“大脑”，它拥有一个“工具箱”（即各种工具，如搜索引擎、计算器、SQL数据库查询器）。当收到一个任务（例如“帮我订一张北京到上海的机票”），代理会：\n    -   思考需要做什么（“查找航班信息，比较价格，然后下单”）。\n    -   决定使用哪个工具（“先调用航班搜索API”）。\n    -   执行工具并获得结果。\n    -   根据结果决定下一步行动（“联系支付API”或“询问用户偏好”）。\n    -   不断循环，直到任务完成。\n\n### 一个典型应用场景：智能问答机器人\n\n没有 LangChain：你需要手动编写代码处理文档加载、文本分割、向量存储、调用API、拼接上下文、处理对话历史...代码会非常复杂且难以维护。\n\n有 LangChain：\n```python\nfrom langchain_community.document_loaders import PyPDFLoader\nfrom langchain.text_splitter import CharacterTextSplitter\nfrom langchain_community.vectorstores import FAISS\nfrom langchain_openai import OpenAIEmbeddings, ChatOpenAI\nfrom langchain.chains import RetrievalQA\n\n# 1. 加载PDF文档\nloader = PyPDFLoader("公司手册.pdf")\ndocuments = loader.load()\n\n# 2. 分割文本\ntext_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)\ntexts = text_splitter.split_documents(documents)\n\n# 3. 创建向量存储\nembeddings = OpenAIEmbeddings()\nvectorstore = FAISS.from_documents(texts, embeddings)\n\n# 4. 创建问答链\nllm = ChatOpenAI(model="gpt-4")\nqa_chain = RetrievalQA.from_chain_type(\n    llm=llm,\n    chain_type="stuff",\n    retriever=vectorstore.as_retriever()\n)\n\n# 5. 提问\nanswer = qa_chain.invoke("我们公司的年假政策是什么？")\nprint(answer)\n```\n几行核心代码就完成了一个典型的 RAG 应用。\n\n### 总结\n\n| 你需要做的 | 传统方式 | 使用 LangChain |\n| :--- | :--- | :--- |\n| 调用不同大模型 | 写不同厂商的 SDK 代码 | 统一接口，一行切换模型 |\n| 让模型使用你的文档 | 手动处理数据、自行设计检索逻辑 | 内置文档加载、分割、向量存储模块 |\n| 构建多步骤任务 | 写大量条件判断、循环代码 | 使用 Chain 或 Agent |\n| 管理对话历史 | 手动维护列表、拼接上下文 | 内置 Memory 模块 |\n| 复用和扩展 | 难以复用，修改成本高 | 模块化设计，易于组合 |\n\n**一句话概括：LangChain 是为了让开发者不必从零处理大模型应用中的各种“脏活累活”，从而可以专注于构建业务逻辑和用户体验的强大框架。** 它是当前构建生成式 AI 应用（特别是 RAG 和 Agent）最流行、最基础的框架之一。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1405, 'prompt_tokens': 8, 'total_tokens': 1413, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 214, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '1b93d0b9-a16a-4107-96d0-8907be08386b', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--8ca58d42-7fe7-475e-ad7c-f15bd0c69dbe-0' usage_metadata={'input_tokens': 8, 'output_tokens': 1405, 'total_tokens': 1413, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 214}}

# %% [markdown]
# 方式2：

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

#加载配置文件
dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# 1、获取对话模型：
chat_model = ChatOpenAI(
    #必须要设置的3个参数
    model_name="deepseek-v4-flash",  #默认使用的是gpt-3.5-turbo模型
    #当没有显式的声明base_url和api_key的时候，默认会从环境变量中查找
)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)
# Out:
# content='这是一个非常经典的问题。简单来说，**LangChain 是一个开源框架，专门用来简化基于大语言模型（LLM）的应用程序开发。**\n\n它的核心目标是让开发者能够像搭乐高积木一样，将不同的组件（如模型、提示词、数据源、外部工具）组合起来，构建出强大的 AI 应用。\n\n为了更好地理解，我们可以从它要**解决的核心痛点**和**核心功能**两个角度来拆解。\n\n### 一、LangChain 要解决什么问题？\n\n在 LangChain 出现之前，开发一个能与外部世界交互的 LLM 应用（比如一个能查询公司内部文档的 AI 客服）会遇到很多麻烦：\n\n1.  **缺乏记忆：** LLM 本身不记忆对话历史，每次对话都是独立的。你需要自己编写代码来管理历史消息。\n2.  **数据隔离：** LLM 的知识截止于训练数据，无法访问你的私有数据库、PDF文件或实时网络信息。\n3.  **无法使用工具：** LLM 只能生成文本，不能计算、不能搜索、不能调用API。你需要自己写代码去调用这些功能。\n4.  **流程复杂：** 一个简单的“查资料→总结→回答”流程，需要你写大量胶水代码来管理步骤和状态。\n\nLangChain 通过提供一套标准化的抽象和接口，将以上这些复杂工作全部封装起来，让开发者可以**用几行代码**就实现上述功能。\n\n### 二、LangChain 的核心概念（搭建积木）\n\n就像乐高积木有不同形状的颗粒，LangChain 也有一系列核心组件：\n\n1.  **Models（模型）：**\n    -   **LLM：** 包装了各种大语言模型（如 OpenAI 的 GPT-4、Anthropic 的 Claude、Google 的 Gemini、开源的 Llama 等），让你可以统一方式调用它们。\n    -   **Chat Models：** 专门为聊天场景优化的模型接口。\n    -   **Embeddings：** 将文本转化为向量（语义上的数字表示），用于语义搜索。\n\n2.  **Prompts（提示模板）：**\n    -   管理、优化和复用提示词。比如，你可以定义一个“翻译提示模板”，只需填入`{source_language}`和`{text}`即可。\n\n3.  **Chains（链）：**\n    -   **核心概念！** 将一个 LLM 调用与另一个组件（如另一个 LLM、一个搜索工具、一个数据库查询）连接起来，形成一个工作流。例如：`检索链` = `搜索数据库` -> `将结果放入提示词` -> `调用LLM回答`。\n\n4.  **Agents（代理）：**\n    -   赋予 LLM “思考”和“行动”的能力。代理会根据用户的输入，**自主决定**使用哪个工具（如搜索、计算器、代码解释器），然后根据工具返回的结果决定下一步行动，直到最终给出答案。\n\n5.  **Memory（记忆）：**\n    -   让应用“记住”对话历史。LangChain 提供了多种记忆实现，如缓冲记忆（记住最近N轮）、窗口记忆、实体记忆（记住特定人物或地点）等。\n\n6.  **Retrievers（检索器）：**\n    -   负责从外部数据源（如向量数据库、文档、API）中检索相关信息，并将其提供给 LLM 使用。这是实现 **RAG（检索增强生成）** 的关键组件。\n\n### 三、LangChain 的典型应用场景\n\n-   **RAG（检索增强生成）：** 构建一个基于公司内部文档的问答机器人。用户提问 -> 检索器在文档中搜索相关片段 -> 系统将问题和片段一起发给 LLM -> LLM 基于片段生成答案。**（这是目前最主流的使用场景）**\n-   **智能客服机器人：** 具备记忆、知识库查询、调用订单查询API等能力的复杂机器人。\n-   **自主工作流代理：** 一个能自动分析数据、生成报告、发送邮件的 AI 助手。\n-   **聊天机器人：** 管理复杂的多轮对话，提升对话的连贯性。\n-   **代码分析工具：** 理解代码库，自动生成文档或辅助调试。\n\n### 总结\n\n**LangChain 就是一个“大模型应用的开发框架”，它抽象了与 LLM 交互的通用模式（如链、代理、记忆、RAG），让你可以像搭积木一样快速构建复杂的 AI 应用，而不是从零开始编写所有底层代码。**\n\n**一个小提示：** 虽然 LangChain 非常流行（尤其是 Python 版本），但它的抽象层有时也会带来复杂性。对于非常简单的应用（比如一次性翻译），直接调用 API 可能更简单。但当你需要构建多步骤、涉及工具或外部数据的应用时，LangChain 的优势就会非常明显。它也提供了 TypeScript/JavaScript 版本，方便前端或全栈开发者使用。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1268, 'prompt_tokens': 8, 'total_tokens': 1276, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 229, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '49f95723-d34a-47cc-b848-c4b02f784dd3', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--c235754b-f922-4a58-a4a8-3563c32a1991-0' usage_metadata={'input_tokens': 8, 'output_tokens': 1268, 'total_tokens': 1276, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 229}}

# %% [markdown]
# 体会其它参数的使用：

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

#加载配置文件
dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# 1、获取对话模型：
chat_model = ChatOpenAI(
    model="deepseek-v4-flash",
    temperature=0.7,  # 温度
    max_tokens=20,  # 最大生成长度
)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)
# Out:
# content='当然可以。LangChain 是一个用于开发由大语言模型（LLM，如 GPT-4、Claude、文心一言等）驱动的应用程序的**开源框架**。\n\n它之所以被广泛使用，是因为它解决了一个核心痛点：**单独的大语言模型本身就像一个“聪明但信息孤立的大脑”**——它只知道训练数据截止之前的知识，无法访问你的私有数据，无法自主执行操作（比如发邮件、查询数据库），也无法记住对话历史。\n\nLangChain 通过“链”（Chain）和“代理”（Agent）等抽象概念，将大语言模型与**外部数据源**（如文档、数据库、搜索引擎）和**外部工具**（如计算器、API）连接起来，让开发者能够轻松构建复杂的、有实用价值的 AI 应用。\n\n### LangChain 的核心组件\n\n为了更好地理解，可以把 LangChain 想象成一个**乐高积木盒**，它提供了各种基础积木，你可以把它们组合起来搭建复杂的 AI 应用。\n\n1.  **模型（Models）**：\n    -   这是最核心的积木，支持接入各种 LLM（如 OpenAI、Anthropic、Google PaLM）和聊天模型。\n    -   也支持嵌入模型（Embedding Models），用于将文本转换为向量，以便进行语义搜索。\n\n2.  **提示（Prompts）**：\n    -   提供了管理提示（Prompt）的工具，包括**模板化**（如“请用{语气}的风格写一篇关于{主题}的文章”）、动态加载、输出解析（让模型输出 JSON 或表格格式，而不是纯文本）等。\n\n3.  **数据连接（Data Connection）**：\n    -   **这是最强大的功能之一**。它解决了“如何让 LLM 使用你的私有数据？”的问题。核心流程是：\n        -   **加载**：从 PDF、网页、数据库、云盘等 40 多种源加载文档。\n        -   **分割**：将长文档切分成小段（块），以适应 LLM 的输入长度和提升搜索精度。\n        -   **向量化**：将每个文本段转换成向量（数字数组）。\n        -   **存储**：将向量存入**向量数据库**（如 Chroma、Pinecone、Weaviate）。\n        -   **检索**：当用户提问时，将问题向量化，然后在向量数据库中搜索最相似的文本段，最后将这些文本段作为“上下文”发给 LLM 一起处理。\n\n4.  **链（Chains）**：\n    -   链是 LangChain 的灵魂。它把 **模型、提示、数据、工具** 等组件串联起来，形成一个可执行的任务流程。\n    -   **简单链**：比如“用户输入 -> 提示模板 -> LLM -> 输出解析”。\n    -   **复杂链**：比如“用户提问 -> 检索相关文档 -> 将这些文档和问题一起发给 LLM -> LLM 写出草稿 -> 将草稿通过翻译模型翻译成英文 -> 输出”。这就是大名鼎鼎的 **RAG（检索增强生成）** 模式，也是目前最主流的企业级 AI 应用架构。\n\n5.  **代理（Agents）**：\n    -   代理让 LLM 不再是“被动响应”，而是能“主动决策”并调用工具。\n    -   比如，你问：“帮我查一下今天纽约的天气，然后把结果用英文邮件发给张三”。\n    -   代理会：1. 调用天气 API 获取数据 -> 2. 调用邮件发送工具 -> 3. 用 LLM 生成邮件正文。整个过程 LLM 充当了“决策大脑”。\n\n6.  **记忆（Memory）**：\n    -   默认情况下，LLM 是无状态的（每次对话都是独立的）。记忆组件负责存储和检索对话历史，让 AI 能记住上下文，进行连贯的多轮对话。\n\n### LangChain 的典型应用场景\n\n-   **企业知识库问答（RAG 聊天机器人）**：公司内部文档（如 HR 政策、产品手册）的智能客服。员工提问，机器人能根据内部文档准确回答，而不仅仅是依赖通用知识。\n-   **文档摘要与分析**：自动阅读长篇报告、合同、法律文件，生成摘要、提取关键信息或对比差异。\n-   **自动化工作流**：自动收集数据、分析日志、生成周报、发送通知。\n-   **代码生成助手**：根据需求描述，自动编写、调试或解释代码。\n\n### 总结与类比\n\n**一句话总结**：LangChain 是一个**“AI 应用的胶水和编排框架”**，它让开发者能够轻松地将 LLM 的能力与外部世界连接起来，构建真正有用、智能且可靠的应用程序。\n\n**类比理解**：\n-   **单纯的 LLM** = 一个绝顶聪明的顾问，但他被关在办公室里，只带了一本旧百科全书。\n-   **LangChain** = 给这位顾问配上了**互联网、文件柜（数据）、电脑工具（API）、记事本（记忆）和一位助手（代理/链）**。顾问现在可以查资料、运行计算、记住之前说了什么，并且能执行复杂的任务。\n-   **你的应用** = 利用 LangChain 这个“强化工具箱”打造出的一个“超级智能助理”。\n\n现在，LangChain 已经成为了构建 LLM 应用事实上的行业标准之一。虽然它也有一些竞争框架（如 LlamaIndex 专注于数据索引，AutoGPT 专注于自主代理），但 LangChain 因其全面性、活跃的社区和丰富的生态系统而占据了主导地位。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1426, 'prompt_tokens': 8, 'total_tokens': 1434, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 251, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '14ea39b5-2498-40c2-89a1-5943db674c89', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--2c1dd471-e536-43ed-8f36-0e1edb3d293d-0' usage_metadata={'input_tokens': 8, 'output_tokens': 1426, 'total_tokens': 1434, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 251}}
